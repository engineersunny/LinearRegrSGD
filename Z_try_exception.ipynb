# %%
def create_excel_file(error_text_widget):
    file_path = file1_entry.get()
    output_path = output_entry.get()

    try:
        df = pd.read_excel(file_path)

        ###
        # Read Excel & Ingest tabs 
        # Return dictionary
        ###
        all_tabs = iterate_tabs(file_path)

        ###
        # Call Calculation function
        ###

        # todo: revert to this code to produce 1 file instead of 2
        # res_df = main.calculate(all_tabs)

        final_res_df, res_df_test = main.calculate(all_tabs)

        ###
        # Save File
        ###

        # if there's no user input for file name - save with current date_time
        now = datetime.now()
        now_ = now.strftime('%Y%m%d_%H%M%S')

        if not output_path:            
            output_path = f"Pricing_{now_}.xlsx"
        
        # Extract the file name without path
        file_name = os.path.basename(output_path)

        # Check for invalid characters in the file name
        invalid_chars = set('/ \\')
        if any(char in invalid_chars for char in file_name):
            result_label.config(text="Error: Output filename contains invalid characters.")
        ## Save file
        else:
            final_res_df.to_excel(output_path, index=False)
            result_label.config(text=f"File saved as: {output_path}")

            #save file for debugging
            # uncomment here to deploy admin program
            output_path_test = f"Pricing_{now_}_Debugging.xlsx"
            res_df_test.to_excel(output_path_test, index=False)


    except Exception as e:
        # error_message = f"Error: {str(e)}"
        # set_error_message(error_text_widget, error_message)  # Display error message in the text widget
        

        current_function_name = inspect.currentframe().f_back.f_code.co_name
        parent_function_name = inspect.currentframe().f_back.f_back.f_code.co_name
        # Construct the error message with the function name
        error_message = f"curr function: {current_function_name}\nparent function: {parent_function_name}\nerror: {str(e)}"
        set_error_message(error_text_widget, error_message)  # Display error message in the text widget

# %%
import pandas as pd

# Creating a DataFrame from a dictionary
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
        'Age': [25, 30, 35, 28],
        'City': ['New York', 'San Francisco', 'Los Angeles', 'Chicago']}

df = pd.DataFrame(data)

# Display the DataFrame
print(df)

# Accessing specific columns
print("Name Column:")
print(df['Name'])

# Accessing specific rows
print("Row 2:")
print(df.loc[1])

# Filtering the DataFrame
print("People older than 30:")
print(df[df['Age'] > 30])

# %%
my_list = ["apple", "banana", "cherry"]

for index, value in enumerate(my_list):
    print(f"Index: {index}, Value: {value}")
